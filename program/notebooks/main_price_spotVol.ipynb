# %%
# %cd ..
# Out:
# /Users/tkts9/git/JAFEE_2022_winter/program

# %%
import esig
import esig.tosig as ts
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import matplotlib.pyplot as plt
import math
import warnings
import matplotlib.patches as mpatches

from sklearn.preprocessing import MinMaxScaler
from torch import optim
from tqdm import tqdm
from sklearn import utils

from src.generating_process import brownian_motion, simulate_SABR, simulate_SABR_2, cal_spotVol
from src.cvae import CVAE
from src.vae import VAE
from src.create_dataset import MyDataset
from src.custom_loss import CustomLoss
from src.utils import tosig
from src.utils.leadlag import leadlag
from src import logsig_inversion
from src import logsig_inversion_v2
from src import process_discriminator
from src.sig_calculus_func import Lead, Lag

pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

warnings.simplefilter('ignore')

# %%
def generate(cond, input_dim, n_latent, n_samples = None):
    if n_samples is not None:
        randoms = []
        for i in range(n_samples):
            random = np.random.normal(0, 1, size=(1, n_latent))
            randoms.append(random)
    else:
        randoms = np.random.normal(0, 1, size=(1, n_latent))
        cond = torch.Tensor(cond)
    
    randoms = torch.Tensor(randoms).reshape(-1, n_latent)
    cond = torch.Tensor(cond.float()).reshape(-1, input_dim)
    
    samples = generator.decoder(randoms, cond)
    
    return samples

# %% [markdown]
# # Download the data

# %%
DATAs = np.load('Data/DATAs_1000.npy')

# %% [markdown]
# # Create the leadlag data

# %%
leadlag_DATAs = []
for i in range(DATAs.shape[0]):
    timestamp = DATAs[i, :, 0]
    price = DATAs[i, :, 1] - DATAs[i, 0, 1]
    vol = DATAs[i, :, 2] - DATAs[i, 0, 2]
    spot_vol = DATAs[i, :, 3] - DATAs[i, 0, 3]

    leadlag_timestamp = leadlag(timestamp)
    leadlag_price = leadlag(price)
    leadlag_vol = leadlag(vol)
    leadlag_spot_vol = leadlag(spot_vol)

    leadlag_DATA = np.c_[leadlag_timestamp, leadlag_price, leadlag_vol, leadlag_spot_vol]
    leadlag_DATAs.append(leadlag_DATA)

leadlag_DATAs = np.array(leadlag_DATAs)

# %% [markdown]
# # Make the explanatory variable

# %%
sig_order = 2
exp_col = [2, 3, 6, 7]

# %%
orig_logsig = []
for i in tqdm(range(leadlag_DATAs.shape[0]), desc="Computing log-signatures"):
    path = leadlag_DATAs[i, :, :]
    
    orig_logsig.append(esig.stream2logsig(path[:, exp_col], sig_order))
    
orig_logsig = np.array(orig_logsig)

scaler = MinMaxScaler(feature_range=(0.00001, 0.99999))
logsig = scaler.fit_transform(orig_logsig)

logsigs = logsig[1:]
conditions = logsig[:-1]

data = utils.as_float_array(logsigs)
data_cond = utils.as_float_array(conditions)

input_dim = data.shape[1]
cond_dim = data_cond.shape[1]
# Out:
# Computing log-signatures: 100%|███████████| 1000/1000 [00:00<00:00, 2271.33it/s]

# %%
log_sig_keys = esig.logsigkeys(len(exp_col), sig_order)
print(log_sig_keys)
# Out:
#  1 2 3 4 [1,2] [1,3] [1,4] [2,3] [2,4] [3,4]

# %% [markdown]
# # Make the target variable

# %%
target_col = [2, 3, 4, 5]

# %%
orig_logsig_target = []
for i in tqdm(range(leadlag_DATAs.shape[0]), desc="Computing log-signatures"):
    path = leadlag_DATAs[i, :, :]
    
    orig_logsig_target.append(esig.stream2logsig(path[:, target_col], sig_order))
    
orig_logsig_target = np.array(orig_logsig_target)

scaler = MinMaxScaler(feature_range=(0.00001, 0.99999))
logsig_target = scaler.fit_transform(orig_logsig_target)

target_data = utils.as_float_array(logsig_target)

input_dim_target = target_data.shape[1]
# Out:
# Computing log-signatures: 100%|███████████| 1000/1000 [00:00<00:00, 2347.82it/s]

# %%
log_sig_keys = esig.logsigkeys(len(target_col), sig_order)
print(log_sig_keys)
# Out:
#  1 2 3 4 [1,2] [1,3] [1,4] [2,3] [2,4] [3,4]

# %% [markdown]
# # Make the dataset

# %%
dataset = MyDataset(data, data_cond, target_data)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=25, shuffle=True)

# %% [markdown]
# # Train

# %%
n_epochs = 1000
learning_rate=0.005

input_dim = input_dim
input_dim_target = input_dim_target
n_latent = 10

# %%
generator = CVAE(input_dim = input_dim, cond_dim = cond_dim, input_dim_target = input_dim_target, n_latent = n_latent, alpha=0.003)

criterion = CustomLoss()
optimizer = optim.SGD(generator.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.005)

# %%
for i in range(n_epochs):
    loss_sum = 0
    for _, (inputs, target) in enumerate(dataloader):
        data = inputs[0]
        cond = inputs[1]
        
        optimizer.zero_grad()
        
        mn, sd, sample_z, output = generator(data, cond)
        
        loss = criterion(mn = mn, sd = sd, outputs = output, targets = target, alpha = 0.003)
        loss.backward()
        
        optimizer.step()
        
        loss_sum += loss
    
    if i % 10 == 0:
        print(loss_sum / len(dataloader))
# Out:
# tensor(0.2443, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1668, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1606, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1540, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1464, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1390, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1328, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1284, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1253, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1232, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1217, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1206, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1195, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1188, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1184, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1176, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1173, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1169, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1166, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1163, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1161, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1160, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1159, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1156, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1155, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1154, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1154, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1152, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1151, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1147, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1147, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1147, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1147, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1150, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1148, dtype=torch.float64, grad_fn=<DivBackward0>)
# tensor(0.1149, dtype=torch.float64, grad_fn=<DivBackward0>)

# %% [markdown]
# # Generate the process

# %%
# Pip size
price_pip = 0.01
spot_vol_pip = 0.0000045

# Number of pips for search space
price_n_pips = 100
spot_vol_n_pips = 1000 
# Number of points
n_points = 100

n_iterations = 50
n_organisms = 100

# %%
generated_path = []
generated_logsigs = []
for cond in data_cond[:100]:
    generated_logsig = generate(cond, cond_dim, n_latent).to('cpu').detach().numpy().copy()
    recovered_path, loss = logsig_inversion_v2.train(generated_logsig, sig_order, n_iterations, n_organisms, n_points, price_pip, spot_vol_pip, price_n_pips, spot_vol_n_pips)
    
    generated_path.append(recovered_path)
    generated_logsigs.append(generated_logsig)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <module>
#       3 for cond in data_cond[:100]:
#       4     generated_logsig = generate(cond, cond_dim, n_latent).to('cpu').detach().numpy().copy()
# ----> 5     recovered_path, loss = logsig_inversion_v2.train(generated_logsig, sig_order, n_iterations, n_organisms, n_points, price_pip, spot_vol_pip, price_n_pips, spot_vol_n_pips)
#       7     generated_path.append(recovered_path)
#       8     generated_logsigs.append(generated_logsig)
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:141, in train(sig, order, n_iterations, n_organisms, n_points, price_pip, spot_vol_pip, price_n_pips, spot_vol_n_pips, top_p, mutation_prob)
#     138 pbar = tqdm(range(n_iterations))
#     140 for _ in pbar:
# --> 141     loss = population.evolve(sig, p=top_p, order=order, mutation_prob=mutation_prob)
#     142     pbar.set_description(f"Loss: {loss}")
#     143     pbar.refresh()
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:126, in Population.evolve(self, sig, p, order, mutation_prob)
#     123     i, j = np.random.choice(range(len(parents)), size=2)
#     124     parent1, parent2 = parents[i], parents[j]
# --> 126 child = parent1 + parent2
#     127 child.mutate(prob=mutation_prob)
#     129 new_generation.append(copy.deepcopy(child))
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:39, in Oganism.__add__(self, other)
#      36 price_path = leadlag(prices)
#      37 spot_voL_path = leadlag(spot_vols)
# ---> 39 o = Oganism(self.n_points, self.price_pip, self.spot_vol_pip, self.price_n_pips, self.spot_vol_n_pips)
#      41 o.price_derivatives = price_derivatives
#      42 o.spot_vol_derivatives = spot_vol_derivatives
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:16, in Oganism.__init__(self, n_points, price_pip, spot_vol_pip, price_n_pips, spot_vol_n_pips)
#      13 self.spot_vol_n_pips = spot_vol_n_pips
#      15 # Initialise
# ---> 16 self.randomise()
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:49, in Oganism.randomise(self)
#      48 def randomise(self):
# ---> 49     self.price_derivatives = np.array([self.random_price_derivative() for _ in range(self.n_points - 1)])
#      50     prices = np.r_[0., self.price_derivatives.cumsum()]
#      52     self.spot_vol_derivatives = np.array([self.random_spot_vol_derivative() for _ in range(self.n_points - 1)])
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:49, in <listcomp>(.0)
#      48 def randomise(self):
# ---> 49     self.price_derivatives = np.array([self.random_price_derivative() for _ in range(self.n_points - 1)])
#      50     prices = np.r_[0., self.price_derivatives.cumsum()]
#      52     self.spot_vol_derivatives = np.array([self.random_spot_vol_derivative() for _ in range(self.n_points - 1)])
#
# File ~/git/JAFEE_2022_winter/program/src/logsig_inversion_v2.py:61, in Oganism.random_price_derivative(self)
#      60 def random_price_derivative(self):
# ---> 61     r = self.price_pip * np.random.randint(-self.price_n_pips, self.price_n_pips)
#      63     return r
#
# KeyboardInterrupt:

# %%
sigs1 = []
for i, path in enumerate(generated_path):
    path_sig = esig.stream2sig(leadlag(path), sig_order)
    sigs1.append(path_sig)
sigs1 = np.array(sigs1)
    
sigs2 = []
for i in range(100):
    path = leadlag_DATAs[i][:, [4, 5]]
    path_sig = esig.stream2sig(path, sig_order)
    sigs2.append(path_sig)
sigs2 = np.array(sigs2)

# %%
res = process_discriminator.test(sigs1, sigs2, order=sig_order, compute_sigs=False, confidence_level=0.99)

print("Are the generated and real distributions DIFFERENT? {}".format(res))
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Computing signatures of population 1', style=ProgressStyl…
# HBox(children=(FloatProgress(value=0.0, description='Computing signatures of population 2', style=ProgressStyl…
# Are the generated and real distributions DIFFERENT? False

# %%
fig, ax = plt.subplots()
for path1, path2 in zip(DATAs[:100], generated_path):
    vol_path = path1[:, 2] -  path1[0, 2]
    ax.plot(vol_path, 'orange', alpha=0.25)

    ax.plot(path2, 'blue', alpha=0.2)

gray_patch = mpatches.Patch(color = 'orange', label = 'volatility paths')
blue_patch = mpatches.Patch(color = 'blue', label = 'Generated paths')


x = range(0, 101, 20)
ax.set_xticks(x)
ax.set_xticklabels([str(i/100) for i in x])
ax.set_xlabel("Timestamp", fontsize=14)

plt.legend(handles=[blue_patch, gray_patch], fontsize=10)    
#外枠の削除
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)

fig.savefig("Figures/generatedVolFromSpot.png", dpi=300, bbox_inches="tight")
plt.show();

# %%
generated_vol = [path[40] for path in generated_path]
real_vol = [path[40, 2] - path[0, 2] for path in DATAs[:100]]

# 最小値
x_min_gene = min(generated_vol)
x_min_real = min(real_vol)

x_min = min(x_min_gene, x_min_real)

# 最大値
x_max_gene = max(generated_vol)
x_max_real = max(real_vol)

x_max = min(x_max_gene, x_max_real)

# 最小値から最大値の範囲で5間隔
range_bin_width = np.arange(x_min, x_max, 0.001)

fig, ax = plt.subplots()
ax = sns.distplot(real_vol, color = 'orange', bins=range_bin_width, label="Real paths", kde = True)
ax = sns.distplot(generated_vol, color = 'blue', bins=range_bin_width, label="Generated paths", kde = True)


#外枠の削除
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)

plt.xlabel("volatility", fontsize=14)
plt.legend(fontsize=12)
fig.savefig("Figures/generatedVolFromSpot_40.png", dpi=300, bbox_inches="tight")
plt.show();
