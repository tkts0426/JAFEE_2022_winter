# %%
# %cd ..
# Out:
# /home/tkts0426/git/JAFEE_2022_winter/program

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

from src.generate_SABR import CalculateSpotVolatility

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

np.random.seed(1234)

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
DATAs = np.load('Data/DATAs_1000.npy')

# %%
fig, ax = plt.subplots()
for i in range(DATAs.shape[0]):
    timestamp = DATAs[i, :, 0]
    price = DATAs[i, :, 1]
    
    ax.plot(timestamp, price, color = 'blue')
    
    ax.set_xlabel('timestamp')
    ax.set_title('price processes')
    
    #外枠の削除
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(True)
    
fig.savefig("Figures/price_processes.png", dpi=300, bbox_inches="tight");

# %%
fig, ax = plt.subplots()
for i in range(DATAs.shape[0]):
    timestamp = DATAs[i, :, 0]
    volatility = DATAs[i, :, 2]
    
    ax.plot(timestamp, volatility, color = 'red')
    
    ax.set_xlabel('timestamp')
    ax.set_title('volatility processes')
    
    #外枠の削除
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(True)
    
fig.savefig("Figures/volatility_processes.png", dpi=300, bbox_inches="tight");

# %%
fig, ax = plt.subplots()
for i in range(DATAs.shape[0]):
    timestamp = DATAs[i, :, 0]
    volatility = DATAs[i, :, 3]
    
    ax.plot(timestamp, volatility, color = 'green')
    
    ax.set_xlabel('timestamp')
    ax.set_title('spot volatility processes')
    
    #外枠の削除
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().spines['bottom'].set_visible(True)
    
fig.savefig("Figures/spot_volatility_processes.png", dpi=300, bbox_inches="tight");

# %% [markdown]
# # Setting hyper parameter

# %%
# parameter for simulating the SABR model
n = 100
T = 1
alpha = 
beta = 
rho = 
X_0 = 1000
v_0 = 6

# parameter for calculating spot volatility
e = 
K = 
N =

# %% [markdown]
# # Creating the dataset of SABR model with spot volatility

# %%
df_path = cal_spotVol(n, N, M, T, alpha, beta, rho, X_0, vol_0)

# %%
path_amount = 1000

DATAs = []
for i in range(path_amount):
    calSABR_spot = CalculateSpotVolatility(n, T, alpha, beta, rho, X_0, vol_0, e, K, N)
    df_path = calSABR_spot.calculate_spot_volatility()
    
    DATAs.apped(df_path.values)

DATAs = np.array(DATAs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#       3 DATAs = []
#       4 for i in range(1000):
# ----> 5     calSABR_spot = CalculateSpotVolatility(n, T, alpha, beta, rho, X_0, vol_0, e, K, N)
#
# NameError: name 'n' is not defined

# %% [markdown]
# # Parameter tuning for Fourier method

# %%
criterion = CustomLoss()
optimizer = optim.SGD(generator.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.005)

# %%
df_path.head(15)
# Out:
#     timestamp      process  volatility  spot volatility  abs_error_vol
# 0        0.00  1000.000000    6.000000    112830.987345  106830.987345
# 1        0.01   950.283775    6.004799    102926.103608   97219.840314
# 2        0.02   932.105011    5.999555     90981.532151   85389.317039
# 3        0.03   956.419543    5.998347     77916.936047   72179.999917
# 4        0.04   951.330991    5.997737     64820.743875   59114.910571
# 5        0.05   953.468721    5.998206     52872.502228   47153.400792
# 6        0.06   924.762449    5.996009     43287.018491   37742.134848
# 7        0.07   936.946948    5.998372     37284.403271   31664.246979
# 8        0.08   930.871615    5.997106     36066.861007   30484.325443
# 9        0.09   934.705335    5.996748     40764.564894   35159.372320
# 10       0.10   936.321732    5.994048     52311.092459   46698.734723
# 11       0.11   922.908359    5.999291     71230.313528   65693.517797
# ...

# %%
print("L2-error is",cal_error(df_path))
# Out:
# L2-error is 10.930482466628321
